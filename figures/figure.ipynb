# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import matplotlib
plt.style.use("ggplot")
# matplotlib.rcParams['pdf.fonttype'] = 42

# %%
def gen_sel_ranges(raw_ranges):
    mid_sel = []
    for r in raw_ranges:
        mid_sel.append((r[0] + r[1])/2.0)
    return mid_sel

# %% [markdown]
# # default range query (Synthetic)

# %%
uniform_sel = [[0.00099245, 0.0010229], [0.00845605, 0.0100193], [0.0172055, 0.0499664], [0.0499735, 0.0999585], [0.100012, 0.200003]]
range_uniform = {}
range_uniform["rtree"] = [123, 1304.1, 10798.7, 20577.3, 31495.3]
range_uniform["rstar"] = [144, 1708.3, 12654, 24060.8, 37915.7]
range_uniform["ug"   ] = [64824, 75282.5, 78937.8, 119518, 119825]
range_uniform["edg"  ] = [192, 1272.4, 4454.5, 12798.4, 29232]
range_uniform["qdtree"] = [56365.2,129760, 128126, 126608, 77002.1]
#range_uniform['fs'   ] = [74665.4, 91271.9, 113066, 136940, 98284.4]

range_uniform["flood"] = [92.4, 1013.5, 3730.2, 11460.1, 26862.6]
range_uniform["ifi"  ] = [105.6, 745.9, 2962.7, 5221.8, 7736.1]
range_uniform["lisa" ] = [131.3, 2799.6, 8086.7, 17905.1, 37808.3]
range_uniform["mli"  ] = [900.5, 7652.7, 41533.4, 85301.1, 113519]
#range_uniform["rsmi" ] = [319.7, 2211.6, 9212.7, 24273.7, 32332.8]
range_uniform["zm"   ] = [136.9, 1926.2, 9463.2, 17277.9, 32469.3]

gaussian_sel = [[0.0002309, 0.0138377], [0.0150262, 0.0562588], [0.0569496, 0.160825], [0.170268, 0.533372], [0.59714, 0.880402]]
range_gaussian = {}
range_gaussian["rtree"] = [718.7, 5157.6, 20556, 60696.1, 88023.5]
range_gaussian["rstar"] = [1075.5, 6463.5, 25359.2, 64511.8, 106409]
range_gaussian["ug"] = [957, 5582.1, 16842.9, 49959.3, 71219.6]
range_gaussian["edg"] = [762.4, 5566.8, 14819, 51638.8, 68568]
range_gaussian["qdtree"] = [19628.1, 18059.1, 21851.9, 28661.3, 30734.1]
range_gaussian['fs'] = [48020.6, 67828, 114693, 139939, 101137]

range_gaussian["flood"] = [495.8, 3258.3, 13541.3, 51104.2, 66460.5]
range_gaussian["ifi"] = [679, 3170, 9906.6, 27674.1, 44225.9]
range_gaussian["lisa"] = [696.6, 3603.6, 14495.5, 50482.9, 65160.3]
range_gaussian["mli"] = [3666.7, 24922.4, 69453.5, 162521, 178527]
range_gaussian["rsmi"] = [5053.8, 10931.4, 37169.7, 88914.7, 96575.0]
range_gaussian["zm"] = [745.9, 4939.7, 20895.5, 54318.2, 98529.8]

lognormal_sel = [[0.00419625, 0.0130009], [0.0139859, 0.231524], [0.252178, 0.325454], [0.326766, 0.629464], [0.629556, 0.840773]]
range_lognormal = {}
range_lognormal["rtree"] = [1985.1, 20165.8, 49284.8, 71299.4, 103395]
range_lognormal["rstar"] = [2266.9, 13328.6, 54606.1, 103364, 117387]
range_lognormal["ug"] = [3476.3, 22174.6, 94276.3, 161558, 118707]
range_lognormal["edg"] = [1874.9, 10059.6, 50610.3, 67672.8, 99261.5]
range_lognormal["qdtree"] = [22019.8, 29914.7, 59633.2, 63046.2, 47482.8]
range_lognormal['fs'] = [37938.9, 91696.3, 154225, 170559, 114603]

range_lognormal["flood"] = [908.6, 7557.1, 37455.3, 62931.6, 89372.5]
range_lognormal["ifi"] = [857.2, 6173.4, 24912.1, 36289.5, 69246.5]
range_lognormal["lisa"] = [959.6, 7766.9, 39778.5, 54638.6, 90249.5]
range_lognormal["mli"] = [15602, 53962.7, 199507, 261092, 231630]
range_lognormal["rsmi"] = [2041.56, 10326.1, 48757.2, 80916.6, 95318.4]
range_lognormal["zm"] = [1346.7, 11290.3, 51273.3, 92768.9, 133701]

# %% [markdown]
# # default kNN query (Synthetic)

# %%
k = [1, 10, 100, 1000, 10000]
knn_uniform = {}
knn_uniform["rtree"] = [6.29, 7.5, 12.55, 40.29, 216.82]
knn_uniform["kdtree"] = [1.01, 8.04, 48.1, 574.71, 21506.1]
knn_uniform["rstar"] = [6.77, 8.55, 14.54, 59.8, 249.49]
knn_uniform["ann"] = [0.89, 8.38, 52.74, 577.97, 22417.8]
#knn_uniform["fs"] = [40057.9, 39774.3, 39904.8, 40273.7, 46577.5]

knn_uniform["lisa"] = [28.08, 21.99, 33.03, 99.52, 514.76]
knn_uniform["mli"] = [11.34, 20.49, 52.6, 166.72, 685.8]
#knn_uniform["rsmi"] = [173.04, 219.01, 291.19, 1147.94, 3849.1]
knn_uniform["zm"] = [0.79, 4.3, 45.27, 466.18, 5748.06]

knn_gaussian = {}
knn_gaussian["rtree"] = [12.24, 13.68, 19.43, 51.35, 290.03]
knn_gaussian["kdtree"] = [1.5, 2.73, 15.98, 407.59, 25937.5]
knn_gaussian["rstar"] = [13.48, 16.1, 25.46, 76.47, 306.26]
knn_gaussian["ann"] = [2.12, 5.18, 41.52, 535.92, 19707.5]
knn_gaussian["fs"] = [35827.4, 35386.2, 34454.6, 35268.9, 44311.5]

knn_gaussian["lisa"] = [11.35, 11.7, 18.01, 57.4, 218.51]
knn_gaussian["mli"] = [8.94, 19.06, 54.42, 195.76, 979.13]
knn_gaussian["rsmi"] = [29.3, 178.1, 279.9, 343.75, 3419.2]
knn_gaussian["zm"] = [3.11, 4.91, 48.03, 553.06, 6929.66]

knn_lognormal = {}
knn_lognormal["rtree"] = [14.04, 13.07, 19.25, 53.51, 257.15]
knn_lognormal["kdtree"] = [1.9, 3.13, 16.67, 388.91, 23677.9]
knn_lognormal["rstar"] = [28.87, 33.01, 50.35, 129.65, 600.87]
knn_lognormal["ann"] = [2.28, 5.23, 38.67, 530.57, 18263.7]
knn_lognormal["fs"] = [34715.4, 34896, 34913.3, 35951.1, 44242.5]

knn_lognormal["lisa"] = [10.16, 12.66, 21.28, 63.85, 231.72]
knn_lognormal["mli"] = [11.79, 32.59, 100.94, 373.02, 1819.48]
knn_lognormal["rsmi"] = [29.1, 31.1, 341.7, 510.3, 3247.8]
knn_lognormal["zm"] = [4306.76, 4166.55, 4102.49, 4277.04, 8744.79]

# %% [markdown]
# # default range query (Real)

# %%
fs_sel = [[0.00080894, 0.00791386], [0.00958147, 0.0243782], [0.0320046, 0.0534438], [0.0830659, 0.131286], [0.133199, 0.391178]]
range_fs = {}
range_fs["rtree"] = [77.3, 292.9, 861.3, 2392.8, 3676.6]
range_fs["rstar"] = [87.6, 306.4, 888.3, 2436.1, 4272]
range_fs["ug"] = [195.7, 287.2, 795.3, 1534.8, 2598.3]
range_fs["edg"] = [103.1, 187.4, 641, 1391.5, 2638.6]
range_fs["qdtree"] = [205.4, 168.4, 458.3, 880.5, 1426.7]
range_fs['fs'] = [10775.7, 8166.4, 15913.1, 16905.9, 12165.6]

range_fs["flood"] = [70.9, 189.1, 627.9, 1425.7, 2339.7]
range_fs["ifi"] = [133.6, 226.7, 598.8, 1334.4, 1950.2]
range_fs["lisa"] = [87.9, 207.7, 600.4, 1479.3, 2261]
range_fs["mli"] = [468.3, 2439.6, 2212.9, 6896, 5887.9]
range_fs["rsmi"] = [244.5, 1129.8, 1506.45, 3228.0, 3943.9]
range_fs["zm"] = [144.4, 373, 1018.2, 2486.5, 3672.2]

toronto_sel = [[0.027217, 0.0703911], [0.078817, 0.131971], [0.139498, 0.250876], [0.282277, 0.332639], [0.335522, 0.433902]]
range_toronto = {}
range_toronto["rtree"] = [12959.1, 24708.7, 59615.6, 77449.7, 79979.4]
range_toronto["rstar"] = [15739.8, 33040.4, 73426.6, 91372.4, 92083.8]
range_toronto["ug"] = [17632.1, 33422.5, 66165, 73694.7, 79612.8]
range_toronto["edg"] = [10396.6, 19470.5, 55144.3, 61163.6, 67677.2]
range_toronto['fs'] = [66153.9, 65683.1, 90312, 96955.7, 87343.2]

range_toronto["flood"] = [14111.4, 22457.1, 61934.8, 71714.5, 73030.1]
range_toronto["ifi"] = [8996.2, 14752.4, 28393.8, 36884.8, 35323.5]
range_toronto["lisa"] = [10943.3, 21497.1, 49991.7, 67006.2, 67320.3]
range_toronto["mli"] = [159474, 155340, 197432, 265767, 168379]
range_toronto["rsmi"] = [0, 0, 0, 0, 0]
range_toronto["zm"] = [23463.6, 43124.5, 97405.1, 119790, 105590]

osm_sel = [[0.000633667, 0.0102167], [0.0313029, 0.0778672], [0.0967322, 0.201951], [0.250464, 0.382001], [0.427198, 0.803451]]
range_osm = {}
range_osm["rtree"] = [1758.1, 28953.6, 82898.5, 233287, 297338]
range_osm["rstar"] = [2089.2, 31946.3, 90057, 251268, 261285]
range_osm["ug"] = [1278.5, 25519.1, 62019.4, 201119, 215530]
range_osm["edg"] = [1145.5, 22962.7, 59850.2, 195035, 212991]
range_osm["qdtree"] = [19716.2, 31561.3, 56516.4, 115060, 99684]
range_osm['fs'] = [80871.5, 113004, 158327, 254480, 223052]

range_osm["flood"] = [1157, 23678.6, 65490.3, 197643, 195799]
range_osm["ifi"] = [1018.8, 14776.6, 37895.3, 87777.2, 101191]
range_osm["lisa"] = [1189.5, 22634, 64030.1, 187649, 211325]
range_osm["mli"] = [12291.6, 91459.2, 218828, 496287, 462711]
range_osm["rsmi"] = [0, 0, 0, 0, 0]
range_osm["zm"] = [1748.8, 37125.6, 93480.9, 248685, 276177]

# %% [markdown]
# # default kNN query (Real)

# %%
k = [1, 10, 100, 1000, 10000]
knn_fs = {}
knn_fs["rtree"] = [10.36, 11.35, 17.25, 48.78, 352.81]
knn_fs["kdtree"] = [1.18, 1.77, 15.64, 310.25, 13714.8]
knn_fs["rstar"] = [9.62, 11.21, 17.03, 46.6, 219.48]
knn_fs["ann"] = [1.99, 4.32, 31.86, 410.18, 11048.1]
knn_fs["fs"] = [6378.03, 6570.68, 7142.78, 7449.95, 15549.1]

knn_fs["lisa"] = [49.7, 50.5, 60.81, 92.62, 269.96]
knn_fs["mli"] = [33.32, 89.89, 116.63, 163.28, 350.49]
knn_fs["rsmi"] = [48.32, 76.41, 109.1, 238.8, 497.9]
knn_fs["zm"] = [1104.36, 1087.56, 1149.78, 1405.37, 5022.55]

knn_toronto = {}
knn_toronto["rtree"] = [13.25, 16.16, 25.39, 84.22, 624.47]
knn_toronto["kdtree"] = [2.16, 3.47, 14.78, 277.53, 24281.9]
knn_toronto["rstar"] = [28.73, 35.03, 46.97, 113.83, 453.45]
knn_toronto["ann"] = [2.99, 7.08, 31.74, 354.21, 19641.2]
knn_toronto["fs"] = [55731, 51145, 51488.8, 53261.1, 71639.6]

knn_toronto["lisa"] = [225.04, 282.34, 571.92, 970.98, 2007.43]
knn_toronto["mli"] = [436.41, 755.9, 2004.76, 6014.86, 17743.8]
knn_toronto["rsmi"] = [0, 0, 0, 0, 0]
knn_toronto["zm"] = [27964.6, 27871.2, 28074, 28559.7, 44155.8]

knn_osm = {}
knn_osm["rtree"] = [15.22, 15.24, 20.82, 55.12, 263.23]
knn_osm["kdtree"] = [2.04, 1.58, 7.31, 222.58, 21209]
knn_osm["rstar"] = [22.82, 27.09, 40.05, 94.37, 333.53]
knn_osm["ann"] = [2.92, 3.26, 14.35, 230.03, 16807.3]
knn_osm["fs"] = [111838, 115175, 112250, 112868, 126955]

knn_osm["lisa"] = [35.16, 33.98, 42.21, 88.89, 257.23]
knn_osm["mli"] = [35.89, 115.25, 502.66, 1710.01, 5048.51]
knn_osm["rsmi"] = [0, 0, 0, 0, 0]
knn_osm["zm"] = [57.55, 58.41, 78.77, 238.16, 4505.77]

# %%
uniform_x = gen_sel_ranges(uniform_sel)
uniform_x = [100*xx for xx in uniform_x]
x = np.arange(len(uniform_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(x-5*w, range_uniform['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_uniform['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_uniform['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_uniform['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
#ax.bar(x-w, range_uniform['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x-w, range_uniform['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x, range_uniform['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+w, range_uniform['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+2*w, range_uniform['mli'], width=w, label="MLI", edgecolor='k', linewidth=1, hatch='\\\\')
#ax.bar(x+4*w, range_uniform['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+3*w, range_uniform['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1, hatch='//')

ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['0.1%', '1%', '4%', '10%', '20%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_uniform_range.pdf")

# %%
gaussian_x = gen_sel_ranges(gaussian_sel)
gaussian_x = [100*xx for xx in gaussian_x]
x = np.arange(len(gaussian_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x-5*w, range_gaussian['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_gaussian['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_gaussian['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_gaussian['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
ax.bar(x-w,   range_gaussian['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,     range_gaussian['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+w,   range_gaussian['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+2*w, range_gaussian['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+3*w, range_gaussian['mli'], width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+4*w, range_gaussian['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+5*w, range_gaussian['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1,hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['0.7%', '4%', '10%', '35%', '73%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_gaussian_range.pdf")

# %%
lognormal_x = gen_sel_ranges(lognormal_sel)
lognormal_x = [100*xx for xx in lognormal_x]
x = np.arange(len(lognormal_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x-5*w, range_lognormal['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_lognormal['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_lognormal['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_lognormal['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
ax.bar(x-w,   range_lognormal['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,     range_lognormal['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+w,   range_lognormal['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+2*w, range_lognormal['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+3*w, range_lognormal['mli'], width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+4*w, range_lognormal['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+5*w, range_lognormal['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1,hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['0.9%', '12%', '29%', '48%', '74%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_lognormal_range.pdf")

# %%
fs_x = gen_sel_ranges(fs_sel)
fs_x = [100*xx for xx in fs_x]
x = np.arange(len(fs_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x-5*w, range_fs['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_fs['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_fs['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_fs['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
ax.bar(x-w,   range_fs['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,     range_fs['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+w,   range_fs['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+2*w, range_fs['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+3*w, range_fs['mli'], width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+4*w, range_fs['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+5*w, range_fs['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1,hatch='//')
# ax.plot([x+4*w], [10], color='r', marker='X', markersize=8)
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['0.4%', '1.7%', '4%', '10%', '26%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_fs_range.pdf")

# %%
toronto_x = gen_sel_ranges(toronto_sel)
toronto_x = [100*xx for xx in toronto_x]
x = np.arange(len(fs_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x-5*w, range_toronto['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_toronto['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_toronto['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_toronto['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
ax.bar(x-w,   range_toronto['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,     range_toronto['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+w,   range_toronto['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+2*w, range_toronto['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+3*w, range_toronto['mli'], width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+4*w, range_toronto['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+5*w, range_toronto['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1,hatch='//')
ax.plot([x+4*w], [12], color='r', marker='X', markersize=8)
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['4.8%', '10%', '20%', '30%', '38%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_toronto_range.pdf")

# %%
osm_x = gen_sel_ranges(osm_sel)
osm_x = [100*xx for xx in osm_x]
x = np.arange(len(osm_x))
w=0.07
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x-5*w, range_osm['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-4*w, range_osm['rstar'], width=w, label="R*-tree", edgecolor='k', linewidth=1)
ax.bar(x-3*w, range_osm['ug'], width=w, label='UG', edgecolor='k', linewidth=1)
ax.bar(x-2*w, range_osm['edg'], width=w, label="EDG", edgecolor='k', linewidth=1)
ax.bar(x-w,   range_osm['fs'], width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,     range_osm['flood'], width=w, label="Flood", edgecolor='k', linewidth=1,hatch='xx')
ax.bar(x+w,   range_osm['ifi'], width=w, label="IFI", edgecolor='k', linewidth=1,hatch='..')
ax.bar(x+2*w, range_osm['lisa'], width=w, label="Lisa", edgecolor='k', linewidth=1,hatch='//')
ax.bar(x+3*w, range_osm['mli'], width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+4*w, range_osm['rsmi'], width=w, label="RSMI", edgecolor='k', linewidth=1,hatch='xx')
ax.plot([x+4*w], [12], color='r', marker='X', markersize=8)
ax.bar(x+5*w, range_osm['zm'], width=w, label="ZMI", edgecolor='k', linewidth=1,hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('Selectivity', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=['0.5%', '5%', '15%', '31%', '62%'], fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_osm_range.pdf")

# %%
# sinusoidal lines with colors from default color cycle
L = 2*np.pi
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
_, temp_ax = plt.subplots(figsize=(10, 5))
for s in shift:
    temp_ax.plot(x, np.sin(x + s), '-', linewidth=5, label=s)
temp_ax.margins(0)
plt.legend()
plt.show()

# %%
plt.rcParams['axes.prop_cycle']
# Out:
# cycler('color', ['#E24A33', '#348ABD', '#988ED5', '#777777', '#FBC15E', '#8EBA42', '#FFB5B8'])

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_uniform['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_uniform['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_uniform['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_uniform['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
ax.bar(x,     knn_uniform['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x+w,   knn_uniform['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+2*w, knn_uniform['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+3*w, knn_uniform['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+4*w, knn_uniform['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_uniform_knn.pdf")

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_gaussian['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_gaussian['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_gaussian['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_gaussian['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
#ax.bar(x,     knn_gaussian['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x,   knn_gaussian['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+w, knn_gaussian['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
#ax.bar(x+3*w, knn_gaussian['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+2*w, knn_gaussian['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_gaussian_knn.pdf")

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_lognormal['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_lognormal['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_lognormal['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_lognormal['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
ax.bar(x,     knn_lognormal['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x+w,   knn_lognormal['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+2*w, knn_lognormal['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+3*w, knn_lognormal['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+4*w, knn_lognormal['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_lognormal_knn.pdf")

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_fs['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_fs['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_fs['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_fs['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
ax.bar(x,     knn_fs['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x+w,   knn_fs['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+2*w, knn_fs['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+3*w, knn_fs['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+4*w, knn_fs['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
# ax.plot([x+3*w], [1.2], color='r', marker='X', markersize=8)
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_fs_knn.pdf")

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_toronto['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_toronto['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_toronto['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_toronto['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
ax.bar(x,     knn_toronto['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x+w,   knn_toronto['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+2*w, knn_toronto['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+3*w, knn_toronto['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+4*w, knn_toronto['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
ax.plot([x+3*w], [1.2], color='r', marker='X', markersize=8)
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_toronto_knn.pdf")

# %%
k = ['1', '10', '100', '1000', '10000']
x = np.arange(len(k))
w=0.09
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x-4*w, knn_osm['rtree'], width=w, label="STR", edgecolor='k', linewidth=1)
ax.bar(x-3*w, knn_osm['rstar'], width=w, label="R*tree", edgecolor='k', linewidth=1)
ax.bar(x-2*w, knn_osm['kdtree'], color='#8EBA42', width=w, label='kdtree', edgecolor='k', linewidth=1)
ax.bar(x-w,   knn_osm['ann'], color='#FFB5B8', width=w, label="ANN", edgecolor='k', linewidth=1)
ax.bar(x,     knn_osm['fs'], color='#FBC15E', width=w, label="FS", edgecolor='k', linewidth=1)
ax.bar(x+w,   knn_osm['lisa'], color="#E24A33", width=w, label="Lisa", edgecolor='k', linewidth=1, hatch="//")
ax.bar(x+2*w, knn_osm['mli'], color="#348ABD", width=w, label="MLI", edgecolor='k', linewidth=1,hatch='\\\\')
ax.bar(x+3*w, knn_osm['rsmi'], color="#988ED5", width=w, label="RSMI", edgecolor='k', linewidth=1, hatch='xx')
ax.bar(x+4*w, knn_osm['zm'], color="#777777", width=w, label="ZM", edgecolor='k', linewidth=1, hatch='//')
ax.plot([x+3*w], [1.2], color='r', marker='X', markersize=8)
ax.set_yscale('log')
ax.set_ylabel('Avg. Time (us)', fontsize=14)
ax.set_xlabel('k', fontsize=14)
plt.xlim([-0.5, 4.5])
plt.xticks(x, labels=k, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis = 'x')
plt.legend(ncol=6, loc='upper center', fontsize=10)
plt.tight_layout()
plt.savefig("default_osm_knn.pdf")

# %%
import matplotlib.pyplot as plt

# 假设您有以下数据
index_names = ['Index A', 'Index B', 'Index C']
build_times = [10, 15, 8]  # 构建时间（以秒为单位）
index_sizes = [100, 150, 120]  # 索引大小（以MB为单位）

# 创建一个包含两个子图的图表
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10))

# 绘制构建时间
ax1.bar(index_names, build_times, color='skyblue')
ax1.set_ylabel('Build Time (seconds)')
ax1.set_title('Index Build Time')

# 绘制索引大小
ax2.bar(index_names, index_sizes, color='salmon')
ax2.set_ylabel('Index Size (MB)')
ax2.set_title('Index Size')

# 调整子图之间的间距
plt.tight_layout()

# 保存图像（可选）
plt.savefig('index_metrics.png')

# 显示图像
plt.show()

# %%
160356392/(1024*1024)
# Out:
# 152.92777252197266
