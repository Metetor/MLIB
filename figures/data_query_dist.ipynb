lognormal_sel = [0.00419625,0.0056534,0.0058625,0.005878,0.00588245,0.0107759,0.0118085,0.0128456,0.0129931,0.0130009,0.0130029,0.0139859,0.0141306,0.014138,0.01414,0.072633,0.080514,0.0809127,0.0809321,0.0809364,0.231524,0.251164,0.252178,0.252229,0.252241,0.255919,0.277908,0.279081,0.279141,0.279155,0.301244,0.325454,0.326703,0.326766,0.32678,0.359493,0.385551,0.386804,0.386866,0.38688,0.592106,0.627897,0.629464,0.629538,0.629556,0.79329,0.838653,0.840655,0.840752,0.840773]

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 7))
axes[0][0].hist(fs_sel, color="#E24A33", bins=15, edgecolor='black', linewidth=1.2, label="FourSquare")
axes[0][0].legend(fontsize=13, loc="upper center")
axes[0][1].hist(osm_sel, color="#348ABD", bins=15, edgecolor='black', linewidth=1.2, label="OSM")
axes[0][1].legend(fontsize=13, loc="upper center")
axes[0][2].hist(toronto_sel, color="#988ED5", bins=15, edgecolor='black', linewidth=1.2, label="Toronto3d")
axes[0][2].legend(fontsize=13, loc="upper center")
axes[1][0].hist(uniform_sel, color="#FBC15E", bins=15, edgecolor='black', linewidth=1.2, label="Uniform")
axes[1][0].legend(fontsize=13, loc="upper center")
axes[1][1].hist(gaussian_sel, color="#8EBA42", bins=15, edgecolor='black', linewidth=1.2, label="Gaussian")
axes[1][1].legend(fontsize=13, loc="upper center")
axes[1][2].hist(lognormal_sel, color="#777777", bins=15, edgecolor='black', linewidth=1.2, label="Lognormal")
axes[1][2].legend(fontsize=13, loc="upper center")
# fig.text(0.5, 0.08, 'Selectivity', ha='center', va='center', fontsize=14)
# fig.text(0.07, 0.5, 'Count', ha='center', va='center', rotation='vertical', fontsize=14)
plt.subplots_adjust(hspace=0.1)
plt.tight_layout()
plt.savefig("query_distribution.pdf")

# %%
import matplotlib.pyplot as plt

# 假设您有以下数据
index_names = ['rtree', 'rstar', 'kdtree','quadtree','ug','edg','zm','mli','ifi','lisa','flood']
build_times = [9.74, 148.26, 41.662,1.101,2.618,5.022,2.287,114.165,13.023,12.594,6.581]  # 构建时间（以秒为单位）
index_sizes = [314.82, 447.55, 0,0,0.22,0.23,152.61,152.62,153.70,153.12,152.92]  # 索引大小（以MB为单位）

# 创建一个包含两个子图的图表
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# 绘制构建时间
ax1.bar(index_names, build_times, color='skyblue')
ax1.set_ylabel('Build Time (seconds)')
ax1.set_title('Index Build Time')

# 添加构建时间标签
for i, name in enumerate(index_names):
    ax1.text(i, build_times[i] + 0.5, name, ha='center', va='bottom')  # 修改这里

# 绘制索引大小
ax2.bar(index_names, index_sizes, color='salmon')
ax2.set_ylabel('Index Size (MB)')
ax2.set_title('Index Size')

# 添加索引大小标签
for i, name in enumerate(index_names):
    ax2.text(i, index_sizes[i] + 5, name, ha='center', va='bottom')  # 修改这里

# 调整子图之间的间距
plt.tight_layout()

# 保存图像（可选）
plt.savefig('index_metrics.pdf')

# 显示图像
plt.show()
